# %%
import pandas as pd
from sklearn import datasets
from matplotlib import pyplot
from matplotlib import pyplot
from matplotlib import pylab
import numpy as np
from sklearn.decomposition import PCA
from sklearn.decomposition import NMF
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
data = datasets.load_breast_cancer()

# %%
cancer_df = pd.DataFrame(data=np.c_[data['data'], data['target']],columns= list(data['feature_names']) + ['target'])

# %%
cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension   ...    worst texture  worst perimeter  worst area  \
# ...

# %%
pca = PCA(n_components=3, whiten=True)

# %%
decomp_data=pca.fit_transform(cancer_df.drop('target',axis=1))

# %%
pca.explained_variance_ratio_
# Out:
# array([0.98204467, 0.01617649, 0.00155751])

# %%
pyplot.scatter(x=decomp_data[::,0],y=decomp_data[::,1],c=cancer_df['target'])

# %%
pyplot.scatter(x=decomp_data[::,0],y=decomp_data[::,2],c=cancer_df['target'])

# %%
pca.components_
# Out:
# array([[ 5.08623202e-03,  2.19657026e-03,  3.50763298e-02,
#          5.16826469e-01,  4.23694535e-06,  4.05260047e-05,
#          8.19399539e-05,  4.77807775e-05,  7.07804332e-06,
#         -2.62155251e-06,  3.13742507e-04, -6.50984008e-05,
#          2.23634150e-03,  5.57271669e-02, -8.05646029e-07,
#          5.51918197e-06,  8.87094462e-06,  3.27915009e-06,
#         -1.24101836e-06, -8.54530832e-08,  7.15473257e-03,
#          3.06736622e-03,  4.94576447e-02,  8.52063392e-01,
#          6.42005481e-06,  1.01275937e-04,  1.68928625e-04,
#          7.36658178e-05,  1.78986262e-05,  1.61356159e-06],
#        [ 9.28705650e-03, -2.88160658e-03,  6.27480827e-02,
#          8.51823720e-01, -1.48194356e-05, -2.68862249e-06,
#          7.51419574e-05,  4.63501038e-05, -2.52430431e-05,
#         -1.61197148e-05, -5.38692831e-05,  3.48370414e-04,
#          8.19640791e-04,  7.51112451e-03,  1.49438131e-06,
#          1.27357957e-05,  2.86921009e-05,  9.36007477e-06,
# ...

# %%
pyplot.matshow(pca.components_,cmap='viridis')
pyplot.yticks([0,1,2],["1st",'2nd','3rd'])
pyplot.colorbar()
pyplot.xticks(range(31),cancer_df.drop('target',axis=1).columns,
              rotation=45,ha='left')
pyplot.xlabel('feature')
pyplot.ylabel('PC')
# Out:
# Text(0,0.5,'PC')

# %%
len(cancer_df.columns)
# Out:
# 31

# %%
pca.explained_variance_ratio_
# Out:
# array([0.98204467, 0.01617649, 0.00155751])

# %%
decomp_data[0]

# %% [markdown]
# Non Negative Matrix Factorization

# %%
nmf = NMF(n_components=3)
data_nmf = nmf.fit_transform( cancer_df.drop('target',axis=1) )

# %%
pyplot.scatter(x=data_nmf[::,0],y=data_nmf[::,1],c=cancer_df['target'])

# %%
pyplot.scatter(x=data_nmf[::,0],y=data_nmf[::,2],c=cancer_df['target'])

# %%
pyplot.scatter(x=data_nmf[::,1],y=data_nmf[::,2],c=cancer_df['target'])

# %%
pyplot.matshow(nmf.components_,cmap='viridis')
pyplot.yticks([0,1,2],["1st",'2nd','3rd'])
pyplot.colorbar()
pyplot.xticks(range(31),cancer_df.drop('target',axis=1).columns,
              rotation=60,ha='left')
pyplot.xlabel('feature')
pyplot.ylabel('PC')

# %%
iris_data = datasets.load_iris()
iris_df = pd.DataFrame(data=np.c_[iris_data['data'], iris_data['target']],columns= list(iris_data['feature_names']) + ['target'])

# %%
pca = PCA(n_components=2, whiten=True)
decomp_data=pca.fit_transform(iris_df.drop('target',axis=1))
decomp_data
# Out:
# array([[-1.3059028 ,  0.66358991],
#        [-1.32107398, -0.34449998],
#        [-1.405936  , -0.27905426],
#        [-1.33617856, -0.63213207],
#        [-1.32749711,  0.67845686],
#        [-1.10920067,  1.51932013],
#        [-1.37240118, -0.16681722],
#        [-1.27781875,  0.34622394],
#        [-1.40503061, -1.15972851],
#        [-1.30086133, -0.21677267],
#        [-1.21945893,  1.32457995],
#        [-1.27132901,  0.04372491],
#        [-1.35612405, -0.46271497],
#        [-1.56910331, -1.02254743],
#        [-1.28611926,  2.41007147],
#        [-1.15978443,  2.73222729],
#        [-1.2758942 ,  1.66216748],
#        [-1.28844456,  0.6484113 ],
#        [-1.06988095,  1.78641899],
#        [-1.25877865,  1.05748108],
#        [-1.12410469,  0.80837465],
#        [-1.23731792,  0.89404193],
#        [-1.56455794,  0.28772982],
#        [-1.12050295,  0.21439748],
#        [-1.14630886, -0.06341061],
#        [-1.2201354 , -0.28253006],
#        [-1.20122889,  0.28015487],
# ...

# %%
pyplot.scatter(x=decomp_data[::,0],y=decomp_data[::,1],c=iris_df['target'])

# %%
pyplot.matshow(pca.components_,cmap='viridis')
pyplot.yticks([0,1],["1st",'2nd'])
pyplot.colorbar()
pyplot.xticks(range(4),iris_df.drop('target',axis=1).columns,
              rotation=60,ha='left')
pyplot.xlabel('feature')
pyplot.ylabel('PC')
# Out:
# Text(0,0.5,'PC')

# %%
nmf = NMF(n_components=2)
data_nmf = nmf.fit_transform( iris_df.drop('target',axis=1) )

# %%
pyplot.scatter(x=data_nmf[::,0],y=data_nmf[::,1],c=iris_df['target'],cmap='plasma')

# %%
pyplot.matshow(nmf.components_,cmap='viridis')
pyplot.yticks([0,1],["1st",'2nd'])
pyplot.colorbar()
pyplot.xticks(range(4),iris_df.drop('target',axis=1).columns,
              rotation=60,ha='left')
pyplot.xlabel('feature')
pyplot.ylabel('PC')
# Out:
# Text(0,0.5,'PC')
